# %%
import streamlit as st
import matplotlib.pyplot as plt
import numpy as np

def predict_win(target, current_score, wickets_down, overs_done):
    if target <= 0 or current_score <= 0 or overs_done <= 0:
        return 50
    
    overs_remaining = max(20 - overs_done, 0.1)
    required_run_rate = (target - current_score) / overs_remaining
    current_run_rate = current_score / overs_done if overs_done > 0 else 0
    
    wicket_penalty = wickets_down * 5  
    base_prob = 50
    
    if current_run_rate > required_run_rate * 1.3:
        base_prob = 85
    elif current_run_rate > required_run_rate * 1.1:
        base_prob = 70
    elif current_run_rate > required_run_rate * 0.9:
        base_prob = 50
    elif current_run_rate > required_run_rate * 0.7:
        base_prob = 30
    else:
        base_prob = 15
    
    final_prob = max(base_prob - wicket_penalty, 5)
    return final_prob

print("🔮 World Cup Predictor (Fallback Version)")
print("-" * 40)

target = 180
current_score = 120
wickets_down = 5
overs_done = 15

win_prob = predict_win(target, current_score, wickets_down, overs_done)
print(f"Target: {target}")
print(f"Current Score: {current_score}/{wickets_down}")
print(f"Overs: {overs_done}/20")
print(f"Win Probability: {win_prob:.1f}%")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 6
#       2 # WORLD CUP PREDICTOR (Fallback Version)
#       3 # No external dependencies needed!
#       4 # ============================================
#       5
# ----> 6 import streamlit as st
#       7 import matplotlib.pyplot as plt
#       8 import numpy as np
#       9
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
# !pip install streamlit matplotlib numpy -q
# Out:
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\DELL\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
# !pip show streamlit
# Out:
# Name: streamlit
# Version: 1.58.0
# Summary: A faster way to build and share data apps
# Home-page: https://streamlit.io
# Author:
# Author-email: Snowflake Inc <hello@streamlit.io>
# License-Expression: Apache-2.0
# Location: C:\Users\DELL\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages
# Requires: altair, anyio, blinker, cachetools, click, gitpython, httptools, itsdangerous, numpy, packaging, pandas, pillow, protobuf, pyarrow, pydeck, python-multipart, requests, starlette, tenacity, toml, typing-extensions, uvicorn, watchdog, websockets
# Required-by:

# %%
import streamlit
print(streamlit.__file__)
# Out:
# C:\Users\DELL\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\streamlit\__init__.py

# %%
import streamlit as st

# Create a minimal app
st.title("Test")
st.write("Streamlit works!")
# Out:
# 2026-07-05 19:17:06.320 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-05 19:17:07.450
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\DELL\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-07-05 19:17:07.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-05 19:17:07.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-05 19:17:07.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-05 19:17:07.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-05 19:17:07.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import subprocess
subprocess.Popen(["python", "-m", "streamlit", "run", "world_cup_predictor.py"], shell=True)
# Out:
# <Popen: returncode: None args: ['python', '-m', 'streamlit', 'run', 'world_c...>

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\DELL\Documents\World\World_Cup_Predictor
